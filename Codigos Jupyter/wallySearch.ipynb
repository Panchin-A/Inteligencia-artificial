# %% [markdown]
# ## Rotacion

# %%
import cv2 as cv
import math
import numpy as np 

img = cv.imread('C://Users//david//Desktop//IA//Wally//Originnal//Captura1.png',1)
h,w = img.shape[:2]
img2 = np.zeros((h*3, w*3), dtype = "uint8")
for i in range(h):
    for j in range(w):
        img2[int(i*math.cos(math.radians(30))-j*math.sin(math.radians(30)))+200,
             int(i*(math.sin(math.radians(30)))+j*math.cos(math.radians(30)))+50]=img[i,j]
cv.imshow('imagen1', img)
cv.imshow('imagen2', img2)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 10
#       8 for i in range(h):
#       9     for j in range(w):
# ---> 10         img2[int(i*math.cos(math.radians(30))-j*math.sin(math.radians(30)))+200,
#      11              int(i*(math.sin(math.radians(30)))+j*math.cos(math.radians(30)))+50]=img[i,j]
#      12 cv.imshow('imagen1', img)
#      13 cv.imshow('imagen2', img2)
#
# ValueError: setting an array element with a sequence.

# %%
import cv2 as cv
import os

# %%
def rota(img, i):
    for j in range(10, 361, 20):
        h, w = img.shape[:2]
        mw = cv.getRotationMatrix2D((h // 2, w // 2), j, -1)
        img2 = cv.warpAffine(img, mw, (h, w))
        cv.imwrite('C:\\Users\\david\\Desktop\\IA\\Wally\\Originnal' + str(i) + '_' + str(j) + '.png', img2)

# %%
i = 0
imgPaths = 'C:\\Users\\david\\Desktop\\IA\\Wally\\Originnal'
nomFiles = os.listdir(imgPaths)
for nomFile in nomFiles:
    i = i + 1
    imgPath = imgPaths+"\\"+nomFile
    img = cv.imread(imgPath)
    rota(img, i)

# %% [markdown]
# ## Escalamiento

# %%
import cv2 as cv
import numpy as np
img = cv.imread('C://Users//david//Desktop//IA//Wally//Originnal//Captura1.PNG',1)
h,w = img.shape[:2]
print(h, w)
img2 = np.zeros((h*2, w*2) , dtype = "uint8")
print("Valores " + str(img.shape[:2]))
for i in range(h):
    for j in range(w):
        img2[int(i*2),int(j*2)]=img[i,j]

cv.imshow('imagen', img)
cv.imshow('imagen2', img2)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 80 81
# Valores (80, 81)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only length-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 10
#       8 for i in range(h):
#       9     for j in range(w):
# ---> 10         img2[int(i*2),int(j*2)]=img[i,j]
#      12 cv.imshow('imagen', img)
#      13 cv.imshow('imagen2', img2)
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# ### 300 300 Valores(300,300)

# %%
import cv2 as cv 
import os
import numpy as np

# %%
def rotar(img, 1):
    h,w =img.shape[:2]
    mw=cv.getRotationMatrix2D((h//2, w//2),45,-1)
    img2= cv.warpAffine(img,mw,(h,w))
    cv.imwrite(''+str(i)+'.png',img2)

# %%
def escalagris(img,1):
    gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
    cv.imwrite(''+str(i)+'.png',gray)

# %%
i=0
imgPaths=""
nomFiles = os.listdir(imgPaths)
for nomFlie in nomFiles:
    i=i+1
    imgPath= imgPaths+"/"+nomFile
    img=cv.imread(imgPath)
    #rotar(img,1)
    escalagris(img, i)
